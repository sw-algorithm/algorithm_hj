# %% [markdown]
# - 추상자료형
# - 순차 list : 배열 기반: 비효율적
# - 연결 list : 메모리의 동적할당을 기반으로 구현된 list

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# list를 이용한 stack
