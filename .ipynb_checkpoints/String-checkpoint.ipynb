# %% [markdown]
# # String

# %% [markdown]
# String 중간 교체 방법: 뒤에 복사, 중간에 변경, 뒤에 붙여넣기

# %% [markdown]
# ## 패턴 매칭 알고리즘
# - Brute force
#     - O(MN)
# - KMP
#     - O(M+N)
#     - 패턴 전처리
#     - 매칭 실패 시 돌아갈 곳 계산
# - 보이어 무어

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)
