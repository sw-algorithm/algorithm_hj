# %% [markdown]
# # Queue

# %% [markdown]
# - 뒤 삽입, 앞 삭제
# - First in First out
# - front=-1, end=-1

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ### 선형 Queue
# - 초기: front=rear=-1
# - 공백: front=rear
# - 포화: reaer=n-1
#
# - 문제점: 포화로 잘못 인식할 수 있음

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)
