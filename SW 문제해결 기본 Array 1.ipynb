# %% [markdown]
# # SW 문제해결 기본: Array 1

# %% [markdown]
# 시간복잡도 빅오

# %% [markdown]
# ## 1. Exhaustive Search
# 일단 해답 도출하고 알고리즘 좋은거 쓰면서 답 확인하는 용으로 사용
# - Baby Gin: 1 triple(777), 1run(456)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ## 2. Greedy Algorithm
# 순간순간 최적
# 단점: 해를 못찾을 수도 있다
#     1. add to solution set
#     2. 실행가능성 검사
#     3. 부분 해 집합 검사
#
#     - Baby Gin
#         1. 6자리 정수
#         2. 숫자 수 카운트 후 1~0배열에 저장
#         3. triple 조사 후 삭제 | run 조사 후 삭제
#
#         1. 입력한 숫자 순서대로 정렬

# %% [markdown]
# ## 3. Sort
# 자료 정렬(정리)
#
#     - bubble:
#         - 인접한 두 원소 비교 교환
#         - n 원소-> n-1 정렬
#     - counting:
#         - 집합에 각 항목이 몇개씩 있는지 세기
#         - 정수만 적용 가능
#         - 집합 내 가장 큰 정수 알아야 함
#         - O(n+k) (k는 데이터의 최댓값을 의미한다.)
#         - ex. arr[i]=i의 발생 횟수
#     - selection
#     - quick
#     - insertion
#     - merge

# %%
# Bubble sort pseudo code
#
# int temp[9] = { 3, 2, 1, 5, 4, 7, 8, 0, 6 };
# int tempCount = 9;
# int hold=0, loop, i;

# for (loop = 0; loop < tempCount - 1; loop++) {
#     for (i = 0; i < tempCount - 1 - loop; i++) {
#         if (temp[i] > temp[i+1]) {
#             hold = temp[i];
#             temp[i] = temp[i+1];
#             temp[i+1] = hold;
#         }
#     }
# }

# for (i = 0; i < tempCount; i++) {
#     printf("%d", temp[i]);
# }

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)
