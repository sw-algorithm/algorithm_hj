# %% [markdown]
# # Stack1

# %% [markdown]
# - 선형구조: 자료간 관계가 1대1
# - Last in First out
# - push, pop
# - isEmpty, peek(제일 top 반환)
# - 맨 밑에 -1
# - 1차원배열: 구현은 용이, 스택 크기 변경 힘듬
# - 저장소를 동적으로 할당하여 스택 구현 - 동적 연결리스트(메모리 효율적)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# - 괄호 검사
#     - ( 를 스택에, ) 읽을 때 ( pop
# - 재귀 호출
#     - 프로그램 크기 줄일 수 있지만 수행시간 소요 많음
# - Memorization
#     - 동적 계획의 핵심
#     - 이전에 계산한 값 메모리에 저장

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ### 동적계획법
# - 입력크기가 작은 부분 해결 후 큰 부분 해결
# 1. 문제 분할
# 2. 가장 작은 부분 해결
# 3. 결과 테이블에 저장 후 그 테이블에 있는 값으로 문제 해결
# - -> iterative

# %% [markdown]
# ### DFS BFS
# - 비선형구조인 그래프에서 많이 쓰임
# - DFS 스택 사용

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)
