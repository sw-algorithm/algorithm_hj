# %% [markdown]
# # Stack 2

# %% [markdown]
# 계산기 - 스택 사용 - 후위표기법으로
# - 연산자 순위가 낮은 것은 스택 밑에 있음

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ### BackTracking
# - 해를 찾는 중에 막히면 다시 되돌아가서 해를 찾아가는 기법
# - 최적화 문제, 결정 문제
# - YES/NO 문제
#     - 미로, N-Queen, Map Coloring, Subset Sum
# - DFS는 무조건 모든 경로 탐색, 백트래킹은 안되는 경로는 차단(가지치기)
# - 상태공간트리
#
# - Power Set
#     - 2의 n승 가지의 수

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ## 분할 정복
# - 분할, 정복, 통합

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)
